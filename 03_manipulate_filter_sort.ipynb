# %% [markdown]
# # How to manipulate, filter and sort an excel file

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
from openpyxl.workbook import workbook

# %% [markdown]
# [Dataset Meteorite Landinds](https://www.kaggle.com/datasets/nasa/meteorite-landings)

# %%
df = pd.read_csv('files/Meteorite_Landings.csv')
df.head(5)
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %% [markdown]
# ## How to get a row filtering with a specific value
# * Get data of meteorite landing in the year 1976

# %%
df.loc[df['year'] == 1976.0]
# Out:
#                        name     id nametype       recclass   mass (g)   fall  \
# 3                  Acapulco     10    Valid    Acapulcoite     1914.0   Fell
# 238                 Dhajala   6698    Valid           H3.8    45000.0   Fell
# 256                    Dowa   7725    Valid     Stone-uncl      642.0   Fell
# 262                  Dunhua   7749    Valid     Stone-uncl        NaN   Fell
# 337               Grefsheim  11196    Valid             L5       45.5   Fell
# 419                   Jilin  12171    Valid             H5  4000000.0   Fell
# 428                   Junan  12210    Valid             L6      950.0   Fell
# 821                Qingzhen  18908    Valid            EH3     2600.0   Fell
# 863                Ruhobobo  22780    Valid             L6      465.5   Fell
# 914                 Sheyang  23531    Valid             L6      605.0   Fell
# 1026                Udaipur  24099    Valid             H3     2000.0   Fell
# 1106               Zhuanghe  30408    Valid             H5     2900.0   Fell
# 2432     Allan Hills A76001   1308    Valid             L6    20151.0  Found
# 2433     Allan Hills A76002   1309    Valid   Iron, IAB-MG     1510.0  Found
# 2434     Allan Hills A76003   1310    Valid             L6    10495.0  Found
# 2435     Allan Hills A76004   1311    Valid          LL3.3      305.0  Found
# 2436     Allan Hills A76005   1312    Valid  Eucrite-pmict     1425.0  Found
# 2437     Allan Hills A76006   1313    Valid             H6     1137.0  Found
# 2438     Allan Hills A76007   1314    Valid             L6      410.0  Found
# 2439     Allan Hills A76008   1315    Valid             H6     1150.0  Found
# 2440     Allan Hills A76009   1316    Valid             L6   407000.0  Found
# 3413                 Alvord   2287    Valid      Iron, IVA    17500.0  Found
# 6851                 Dengli   6650    Valid           H3.8      243.5  Found
# 9180            Dunganville   7748    Valid    Iron, IIIAB    54000.0  Found
# 11705          Fluvanna (b)  10117    Valid             H6     4110.0  Found
# 12627           Gnowangerup  10937    Valid    Iron, IIIAB    33600.0  Found
# 15952        Gunnadorah 002  11455    Valid             L5       46.0  Found
# 16323      Hangman Crossing  11816    Valid             H4     1300.0  Found
# 16367          Haviland (b)  11861    Valid             H5     2092.0  Found
# 16527                Ischgl  56431    Valid            LL6      724.0  Found
# 16557               Jerslev  12084    Valid     Iron, IIAB    40000.0  Found
# 17354             Kimbolton  12312    Valid             H4     7500.0  Found
# 21675          Lookout Hill  14697    Valid            CM2       16.6  Found
# 21793                 Luray  14758    Valid             OC      861.0  Found
# 21675  1976.0 -30.090560  128.805830  (-30.09056, 128.80583)
# 21793  1976.0  39.116670  -98.683330   (39.11667, -98.68333)
# 22903  1976.0  47.900000   37.500000            (47.9, 37.5)
# 26193  1976.0 -77.583890  160.326390  (-77.58389, 160.32639)
# 26194  1976.0 -77.583890  160.373610  (-77.58389, 160.37361)
# 26358  1976.0  34.044720 -102.799170  (34.04472, -102.79917)
# 30977  1976.0  34.466670 -115.233330  (34.46667, -115.23333)
# 32001  1976.0 -30.416670  138.000000      (-30.41667, 138.0)
# 36007  1976.0  35.416670 -117.916670  (35.41667, -117.91667)
# 36297  1976.0  33.883330 -103.566670  (33.88333, -103.56667)
# 36883  1976.0  24.466670 -103.350000     (24.46667, -103.35)
# 37420  1976.0  32.917220 -102.500000      (32.91722, -102.5)
# 37435  1976.0  32.716670 -102.650000     (32.71667, -102.65)
# 37439  1976.0  32.716670 -102.650000     (32.71667, -102.65)
# 37440  1976.0  32.716670 -102.650000     (32.71667, -102.65)
# 37665  1976.0  33.118610 -102.740560  (33.11861, -102.74056)
# 37708  1976.0 -25.066670   14.883330   (-25.06667, 14.88333)
# 38256  1976.0  32.903330 -102.925000    (32.90333, -102.925)
# 38336  1976.0  29.966670  -98.116670   (29.96667, -98.11667)
# 45715  1976.0  33.983330 -115.683330  (33.98333, -115.68333)

# %% [markdown]
# * Now get data of meteorite landing in the year 1976 and named *Acapulco*

# %%
df.loc[(df['year'] == 1976.0) & (df['name'] == 'Acapulco')]
# Out:
#        name  id nametype     recclass  mass (g)  fall    year    reclat  \
# 3  Acapulco  10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
#
#    reclong        GeoLocation
# 3    -99.9  (16.88333, -99.9)

# %% [markdown]
# ## How to apply a *lambda* function
# * Create a new column to store the mass of a meteroite in kg units

# %%
df['mass(kg)'] = df['mass (g)'].apply(lambda x: x / 1000)

# %%
df.head(4)
# Out:
#        name  id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen   1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus   2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee   6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco  10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
#
#      reclong           GeoLocation  mass(kg)
# 0    6.08333     (50.775, 6.08333)     0.021
# 1   10.23333  (56.18333, 10.23333)     0.720
# 2 -113.00000    (54.21667, -113.0)   107.000
# 3  -99.90000     (16.88333, -99.9)     1.914

# %% [markdown]
# ## How to drop columns
# * Create a new dataframe dropping the columns: *fall* and *GeoLocation*

# %%
to_drop = ['fall','GeoLocation']

# %%
df.drop(columns=to_drop, inplace=True)

# %%
df.head(5)
# Out:
#        name   id nametype     recclass  mass (g)    year    reclat    reclong  \
# 0    Aachen    1    Valid           L5      21.0  1880.0  50.77500    6.08333
# 1    Aarhus    2    Valid           H6     720.0  1951.0  56.18333   10.23333
# 2      Abee    6    Valid          EH4  107000.0  1952.0  54.21667 -113.00000
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976.0  16.88333  -99.90000
# 4   Achiras  370    Valid           L6     780.0  1902.0 -33.16667  -64.95000
#
#    mass(kg)
# 0     0.021
# 1     0.720
# 2   107.000
# 3     1.914
# 4     0.780
